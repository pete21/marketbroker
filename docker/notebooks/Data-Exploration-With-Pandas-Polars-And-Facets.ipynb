# %% [markdown]
# # Data exploration
#
# A key part of Data Science is interactive exploration of your dataset. There are arguably many tools to perform data science, but [Python Pandas](https://pandas.pydata.org/) is one of the most widely used. Even with recent developments, Pandas is known to struggle with performance when dealing with demanding datasets, so in the past few years the [Polars project](https://pola.rs/) has become very popular. This notebook explores very basic interactive exploration using both Pandas and Polars, and also with a less known but also cool library, [Facets](https://github.com/PAIR-code/facets).

# %% [markdown]
# ## Data exploration using Pandas

# %%
#This line is needed to display the charts later in the notebook
# %matplotlib widget 
#ignore deprecation warnings in this demo
import warnings
warnings.simplefilter("ignore", category=DeprecationWarning)

# %%
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt


# Database connection details
db_config = {
    'user': 'admin',
    'password': 'quest',
    'host': 'questdb',
    'port': 8812, 
    'database': 'qdb'
}

# Create a database connection
engine = create_engine(f'postgresql://{db_config["user"]}:{db_config["password"]}@{db_config["host"]}:{db_config["port"]}/{db_config["database"]}')
query = 'SELECT * FROM github_events'


df = pd.read_sql(query, engine)

# Display the first few rows of the DataFrame
df.head()

# %%
# Check the data types and null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13860 entries, 0 to 13859
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   repo       13860 non-null  object
#  1   type       13860 non-null  object
#  2   actor      13860 non-null  object
#  3   timestamp  13860 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 433.3+ KB

# %%
# Summary statistics of numerical columns
df.describe()
# Out:
#                            timestamp
# count                          11730
# mean   2024-01-30 12:37:41.430206720
# min       2024-01-30 12:03:24.127240
# 25%    2024-01-30 12:20:28.558031872
# 50%    2024-01-30 12:37:41.578468864
# 75%    2024-01-30 12:54:54.929385216
# max       2024-01-30 13:11:56.653242

# %%
# Count unique values in categorical columns
df['type'].value_counts()
# Out:
# type
# PushEvent                        6644
# CreateEvent                       690
# PullRequestEvent                  419
# IssueCommentEvent                 265
# WatchEvent                        232
# PullRequestReviewEvent            205
# DeleteEvent                       180
# IssuesEvent                       113
# PullRequestReviewCommentEvent      91
# ForkEvent                          81
# ReleaseEvent                       35
# MemberEvent                        19
# PublicEvent                        15
# CommitCommentEvent                  6
# GollumEvent                         5
# Name: count, dtype: int64

# %%
# Plot a bar chart for categorical columns
plt.figure()  # Create another new figure object
df['type'].value_counts().plot(kind='bar')
plt.xlabel('Event Type')
plt.ylabel('Count')
plt.title('Event Type Distribution')
plt.tight_layout()
plt.show()  # Display the plot
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Group the DataFrame by minute intervals and event types
grouped = df.groupby([pd.Grouper(key='timestamp', freq='1Min'), 'type']).size().unstack(fill_value=0)

# Get unique event types
unique_event_types = df['type'].unique()

# Create subplots for each event type
fig, axes = plt.subplots(nrows=len(unique_event_types), figsize=(10, 6 * len(unique_event_types)))

for i, event_type in enumerate(unique_event_types):
    ax = axes[i]
    
    # Create a histogram for the event count of the current type
    ax.hist(grouped[event_type], bins=20, edgecolor='k')
    ax.set_xlabel('Event Count (per minute)')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Distribution of Event Counts for {event_type} (per minute)')

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# polars is not included on the jupyter notebook docker image, so we need to install it
# !pip install polars
# Out:
# Requirement already satisfied: polars in /opt/conda/lib/python3.11/site-packages (0.20.6)

# %%
import polars as pl
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# Database connection details
db_config = {
    'user': 'admin',
    'password': 'quest',
    'host': 'questdb',
    'port': 8812,
    'database': 'qdb'
}

# Create a database connection string
connection_str = f'postgresql://{db_config["user"]}:{db_config["password"]}@{db_config["host"]}:{db_config["port"]}/{db_config["database"]}'

# Create a SQLAlchemy engine
engine = create_engine(connection_str)

# Define your SQL query
query = 'SELECT * FROM github_events'

# Execute the query and fetch data into a pandas DataFrame
df = pd.read_sql(query, engine)

# Convert the pandas DataFrame to a Polars DataFrame
df_polars = pl.DataFrame(df)

# Display the first few rows of the Polars DataFrame
print(df_polars.head())

# Check the schema of the Polars DataFrame
print(df_polars.schema)
# Out:
# shape: (5, 4)
# ┌─────────────────────────────┬─────────────┬─────────────┬────────────────────────────┐
# │ repo                        ┆ type        ┆ actor       ┆ timestamp                  │
# │ ---                         ┆ ---         ┆ ---         ┆ ---                        │
# │ str                         ┆ str         ┆ str         ┆ datetime[ns]               │
# ╞═════════════════════════════╪═════════════╪═════════════╪════════════════════════════╡
# │ cs-jsi/chisel4ml            ┆ PushEvent   ┆ jurevreca12 ┆ 2024-02-02 08:05:12.023344 │
# │ Tarzan22/BES-Backend        ┆ CreateEvent ┆ Tarzan22    ┆ 2024-02-02 08:05:12.026647 │
# │ haoqing0110/addon-framework ┆ CreateEvent ┆ haoqing0110 ┆ 2024-02-02 08:05:12.026703 │
# │ negoxa2020/web_individ      ┆ PushEvent   ┆ negoxa2020  ┆ 2024-02-02 08:05:12.026730 │
# │ estevenson9/sketch          ┆ PushEvent   ┆ estevenson9 ┆ 2024-02-02 08:05:12.026751 │
# └─────────────────────────────┴─────────────┴─────────────┴────────────────────────────┘
# OrderedDict([('repo', String), ('type', String), ('actor', String), ('timestamp', Datetime(time_unit='ns', time_zone=None))])

# %%
# Check the data types and null values
df.describe()
# Out:
#                            timestamp
# count                           5160
# mean   2024-02-02 08:20:29.363307008
# min       2024-02-02 08:05:12.023344
# 25%    2024-02-02 08:12:57.798562560
# 50%    2024-02-02 08:20:31.040339456
# 75%    2024-02-02 08:28:04.566559488
# max       2024-02-02 08:35:37.167323

# %%
df
# Out:
#                                                    repo         type  \
# 0                                      cs-jsi/chisel4ml    PushEvent
# 1                                  Tarzan22/BES-Backend  CreateEvent
# 2                           haoqing0110/addon-framework  CreateEvent
# 3                                negoxa2020/web_individ    PushEvent
# 4                                    estevenson9/sketch    PushEvent
# ...                                                 ...          ...
# 5155                                      235wgdf/repo5    PushEvent
# 5156                                       biqute/qtics  DeleteEvent
# 5157                Samriddhi-Sardar/Audiobook-for-kids  CreateEvent
# 5158  NumtraCG/65bc946c644fb26e5dd63f3720240202-0827...  CreateEvent
# 5159                          ClaudiiaGutierrez/TASCA-4  CreateEvent
#
#                   actor                  timestamp
# 0           jurevreca12 2024-02-02 08:05:12.023344
# 1              Tarzan22 2024-02-02 08:05:12.026647
# 2           haoqing0110 2024-02-02 08:05:12.026703
# 3            negoxa2020 2024-02-02 08:05:12.026730
# 4           estevenson9 2024-02-02 08:05:12.026751
# ...                 ...                        ...
# 5155          ttgds3asu 2024-02-02 08:35:37.167318
# 5156    rodolfocarobene 2024-02-02 08:35:37.167320
# 5157   Samriddhi-Sardar 2024-02-02 08:35:37.167321
# 5158           NumtraCG 2024-02-02 08:35:37.167322
# 5159  ClaudiiaGutierrez 2024-02-02 08:35:37.167323
#
# [5160 rows x 4 columns]

# %%
# Count unique values in categorical columns
event_counts = df.groupby('type').count()
event_counts
# Out:
#                                repo  actor  timestamp
# type
# CommitCommentEvent                1      1          1
# CreateEvent                     479    479        479
# DeleteEvent                     168    168        168
# ForkEvent                        48     48         48
# GollumEvent                       4      4          4
# IssueCommentEvent               199    199        199
# IssuesEvent                      58     58         58
# MemberEvent                      17     17         17
# PublicEvent                      19     19         19
# PullRequestEvent                308    308        308
# PullRequestReviewCommentEvent    56     56         56
# PullRequestReviewEvent           95     95         95
# PushEvent                      3467   3467       3467
# ReleaseEvent                     20     20         20
# WatchEvent                      221    221        221

# %%
# Count unique values in categorical columns
df.groupby('type').value_counts()
# Out:
# type                repo                                            actor             timestamp
# CommitCommentEvent  symious/ratis                                   symious           2024-02-02 08:23:46.779590    1
# CreateEvent         12deeksha/exp1                                  12deeksha         2024-02-02 08:13:53.388973    1
#                     Udaytas/test1                                   Udaytas           2024-02-02 08:33:19.601644    1
#                     clalit-genomics/variant_calling_benchmarker     oferisak          2024-02-02 08:19:00.777596    1
#                     charlotte-bourny/projet-hackaton-2              charlotte-bourny  2024-02-02 08:20:46.965305    1
#                                                                                                                    ..
# WatchEvent          CYBER-x-SACHIYA-SL-MD-BOT/CYBER-PANDA-MD.V.0.4  shubhamkukreja12  2024-02-02 08:22:53.949181    1
#                     CTradeExchange/free-forex-market-data           Findy1111         2024-02-02 08:24:18.493414    1
#                     Bindambc/whatsapp-business-java-api             tnyaguire         2024-02-02 08:15:18.306318    1
#                     BigNerd95/Asuswrt-Configs-Deobfuscator          bartbender        2024-02-02 08:34:54.878452    1
#                     zxing/zxing                                     huangcheng        2024-02-02 08:31:33.789028    1
# Name: count, Length: 5158, dtype: int64

# %% [markdown]
# ## Exploration using specialized libraries, like Facets

# %%
# polars is not included on the jupyter notebook docker image, so we need to install it

# !pip install facets-overview
# Out:
# Requirement already satisfied: facets-overview in /opt/conda/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.11/site-packages (from facets-overview) (1.24.4)
# Requirement already satisfied: pandas>=0.22.0 in /opt/conda/lib/python3.11/site-packages (from facets-overview) (2.1.1)
# Requirement already satisfied: protobuf>=3.20.0 in /opt/conda/lib/python3.11/site-packages (from facets-overview) (4.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=0.22.0->facets-overview) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=0.22.0->facets-overview) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=0.22.0->facets-overview) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.22.0->facets-overview) (1.16.0)

# %%
from facets_overview.generic_feature_statistics_generator import GenericFeatureStatisticsGenerator
from sqlalchemy import create_engine
import pandas as pd
from IPython.core.display import display, HTML
import base64

# Database connection details
db_config = {
    'user': 'admin',
    'password': 'quest',
    'host': 'questdb',
    'port': 8812, 
    'database': 'qdb'
}

# Create a database connection
engine = create_engine(f'postgresql://{db_config["user"]}:{db_config["password"]}@{db_config["host"]}:{db_config["port"]}/{db_config["database"]}')
query = 'SELECT * FROM github_events '

# Execute the query and fetch data into a DataFrame
df = pd.read_sql(query, engine)
proto = GenericFeatureStatisticsGenerator().ProtoFromDataFrames([{'name': 'test', 'table': df}])
proto
# Out:
# datasets {
#   name: "test"
#   num_examples: 15630
#   features {
#     name: "repo"
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 15630
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           type: QUANTILES
#         }
#       }
#       unique: 9298
#       top_values {
#         value: "qgbcs/binance_kline"
#         frequency: 260.0
#       }
#       top_values {
#         value: "fsadg32/repo14"
#         frequency: 163.0
#       }
#       avg_length: 22.043697357177734
#       rank_histogram {
#         buckets {
#           label: "qgbcs/binance_kline"
#           sample_count: 260.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "fsadg32/repo14"
#           sample_count: 163.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "fsadg32/repo12"
#           sample_count: 161.0
#         }
#         buckets {
#           low_rank: 3
#           high_rank: 3
#           label: "fsadg32/repo11"
#           sample_count: 159.0
#         }
#         buckets {
#           low_rank: 4
#           high_rank: 4
#           label: "fsadg32/repo20"
#           sample_count: 156.0
#         }
#         buckets {
#           low_rank: 5
#           high_rank: 5
#           label: "fsadg32/repo16"
#           sample_count: 154.0
#         }
#         buckets {
#           low_rank: 6
#           high_rank: 6
#           label: "fsadg32/repo19"
#           sample_count: 153.0
#         }
#         buckets {
#           low_rank: 7
#           high_rank: 7
#           label: "fsadg32/repo17"
#           sample_count: 151.0
#         }
#         buckets {
#           low_rank: 8
#           high_rank: 8
#           label: "fsadg32/repo18"
#           sample_count: 148.0
#         }
#         buckets {
#           low_rank: 9
#           high_rank: 9
#           label: "235wgdf/repo8"
#           sample_count: 145.0
#         }
#         buckets {
#           low_rank: 10
#           high_rank: 10
#           label: "235wgdf/repo6"
#           sample_count: 140.0
#         }
#         buckets {
#           low_rank: 11
#           high_rank: 11
#           label: "fsadg32/repo13"
#           sample_count: 136.0
#         }
#         buckets {
#           low_rank: 12
#           high_rank: 12
#           label: "bommix/Bin"
#           sample_count: 135.0
#         }
#         buckets {
#           low_rank: 13
#           high_rank: 13
#           label: "235wgdf/repo1"
#           sample_count: 134.0
#         }
#         buckets {
#           low_rank: 14
#           high_rank: 14
#           label: "235wgdf/repo7"
#           sample_count: 130.0
#         }
#         buckets {
#           low_rank: 15
#           high_rank: 15
#           label: "235wgdf/repo9"
#           sample_count: 129.0
#         }
#         buckets {
#           low_rank: 16
#           high_rank: 16
#           label: "235wgdf/repo5"
#           sample_count: 126.0
#         }
#         buckets {
#           low_rank: 17
#           high_rank: 17
#           label: "235wgdf/repo10"
#           sample_count: 126.0
#         }
#         buckets {
#           low_rank: 18
#           high_rank: 18
#           label: "235wgdf/repo3"
#           sample_count: 124.0
#         }
#         buckets {
#           low_rank: 19
#           high_rank: 19
#           label: "fsadg32/repo15"
#           sample_count: 122.0
#         }
#         buckets {
#           low_rank: 20
#           high_rank: 20
#           label: "235wgdf/repo2"
#           sample_count: 119.0
#         }
#         buckets {
#           low_rank: 21
#           high_rank: 21
#           label: "235wgdf/repo4"
#           sample_count: 106.0
#         }
#         buckets {
#           low_rank: 22
#           high_rank: 22
#           label: "hafsa1319/akademi_report"
#           sample_count: 91.0
#         }
#         buckets {
#           low_rank: 23
#           high_rank: 23
#           label: "loveli52/val-h4ck"
#           sample_count: 75.0
#         }
#         buckets {
#           low_rank: 24
#           high_rank: 24
#           label: "Kertexx/AirHub-V3"
#           sample_count: 73.0
#         }
#         buckets {
#           low_rank: 25
#           high_rank: 25
#           label: "loveli52/val-ch3at"
#           sample_count: 68.0
#         }
#         buckets {
#           low_rank: 26
#           high_rank: 26
#           label: "villi3152/f0rt-2"
#           sample_count: 67.0
#         }
#         buckets {
#           low_rank: 27
#           high_rank: 27
#           label: "villi3152/frt-h4ck"
#           sample_count: 66.0
#         }
#         buckets {
#           low_rank: 28
#           high_rank: 28
#           label: "loveli52/f0rt-ch3at"
#           sample_count: 66.0
#         }
#         buckets {
#           low_rank: 29
#           high_rank: 29
#           label: "B74LABgit/CAM"
#           sample_count: 65.0
#         }
#         buckets {
#           low_rank: 30
#           high_rank: 30
#           label: "villi3152/-f0rt-"
#           sample_count: 64.0
#         }
#         buckets {
#           low_rank: 31
#           high_rank: 31
#           label: "villi3152/f0rt-prv"
#           sample_count: 62.0
#         }
#         buckets {
#           low_rank: 32
#           high_rank: 32
#           label: "loveli52/f0rt-s0ft-prv"
#           sample_count: 62.0
#         }
#         buckets {
#           low_rank: 33
#           high_rank: 33
#           label: "villi3152/f0rt-ch"
#           sample_count: 60.0
#         }
#         buckets {
#           low_rank: 34
#           high_rank: 34
#           label: "loveli52/val1k-s0ft"
#           sample_count: 59.0
#         }
#         buckets {
#           low_rank: 35
#           high_rank: 35
#           label: "villi3152/h4acl-f0rt"
#           sample_count: 58.0
#         }
#         buckets {
#           low_rank: 36
#           high_rank: 36
#           label: "thebesttv/vul-arch-package"
#           sample_count: 53.0
#         }
#         buckets {
#           low_rank: 37
#           high_rank: 37
#           label: "l1nky-1337/TimeFn-Updated"
#           sample_count: 40.0
#         }
#         buckets {
#           low_rank: 38
#           high_rank: 38
#           label: "ministryofjustice/cloud-platform-environments"
#           sample_count: 39.0
#         }
#         buckets {
#           low_rank: 39
#           high_rank: 39
#           label: "l1nky-1337/PasterX-Updated"
#           sample_count: 39.0
#         }
#         buckets {
#           low_rank: 40
#           high_rank: 40
#           label: "l1nky-1337/Interic-Updated"
#           sample_count: 35.0
#         }
#         buckets {
#           low_rank: 41
#           high_rank: 41
#           label: "l1nky-1337/Enigma-Solutions"
#           sample_count: 34.0
#         }
#         buckets {
#           low_rank: 42
#           high_rank: 42
#           label: "XputsDev/spectra_access"
#           sample_count: 31.0
#         }
#         buckets {
#           low_rank: 43
#           high_rank: 43
#           label: "Dyex719/treeherder"
#           sample_count: 30.0
#         }
#         buckets {
#           low_rank: 44
#           high_rank: 44
#           label: "brand22/d3"
#           sample_count: 23.0
#         }
#         buckets {
#           low_rank: 45
#           high_rank: 45
#           label: "loveli52/f0rtt-ch"
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 46
#           high_rank: 46
#           label: "ibarami/ibarami.github.io"
#           sample_count: 18.0
#         }
#         buckets {
#           low_rank: 47
#           high_rank: 47
#           label: "leandrohstein/transporteservico-urbs-data"
#           sample_count: 17.0
#         }
#         buckets {
#           low_rank: 48
#           high_rank: 48
#           label: "hotspotlab/hourly"
#           sample_count: 17.0
#         }
#         buckets {
#           low_rank: 49
#           high_rank: 49
#           label: "freecall2019/day"
#           sample_count: 17.0
#         }
#         buckets {
#           low_rank: 50
#           high_rank: 50
#           label: "blackpjotr/discourse"
#           sample_count: 16.0
#         }
#         buckets {
#           low_rank: 51
#           high_rank: 51
#           label: "apponboard2019/api"
#           sample_count: 16.0
#         }
#         buckets {
#           low_rank: 52
#           high_rank: 52
#           label: "mrantonyara/iOSWidgetUniversam"
#           sample_count: 14.0
#         }
#         buckets {
#           low_rank: 53
#           high_rank: 53
#           label: "zirklbch/zirklbch.github.io"
#           sample_count: 13.0
#         }
#         buckets {
#           low_rank: 54
#           high_rank: 54
#           label: "tmmlaarhoven/lichess-knockout"
#           sample_count: 13.0
#         }
#         buckets {
#           low_rank: 55
#           high_rank: 55
#           label: "loveli52/k0repi-4.4"
#           sample_count: 13.0
#         }
#         buckets {
#           low_rank: 56
#           high_rank: 56
#           label: "scalr-automation/terraform-scalr-flat-mirror1"
#           sample_count: 12.0
#         }
#         buckets {
#           low_rank: 57
#           high_rank: 57
#           label: "AnriEU/tg"
#           sample_count: 12.0
#         }
#         buckets {
#           low_rank: 58
#           high_rank: 58
#           label: "tzaym1/HardyBot"
#           sample_count: 11.0
#         }
#         buckets {
#           low_rank: 59
#           high_rank: 59
#           label: "sebast759/sebast759.github.io"
#           sample_count: 11.0
#         }
#         buckets {
#           low_rank: 60
#           high_rank: 60
#           label: "pmrappelet/Demo"
#           sample_count: 11.0
#         }
#         buckets {
#           low_rank: 61
#           high_rank: 61
#           label: "tarpetra/welcome-to-darknet"
#           sample_count: 10.0
#         }
#         buckets {
#           low_rank: 62
#           high_rank: 62
#           label: "supermobiteam2/Tizi"
#           sample_count: 10.0
#         }
#         buckets {
#           low_rank: 63
#           high_rank: 63
#           label: "GuilhermeAntunes15/GuilhermeAntunes15"
#           sample_count: 10.0
#         }
#         buckets {
#           low_rank: 64
#           high_rank: 64
#           label: "B74LABgit/HOBO"
#           sample_count: 10.0
#         }
#         buckets {
#           low_rank: 65
#           high_rank: 65
#           label: "vpnsuperapp/fast"
#           sample_count: 9.0
#         }
#         buckets {
#           low_rank: 66
#           high_rank: 66
#           label: "nabawyhussein/nabawyhussein1"
#           sample_count: 9.0
#         }
#         buckets {
#           low_rank: 67
#           high_rank: 67
#           label: "loveli52/g3nshin-ch3at-k0repi-4.4"
#           sample_count: 9.0
#         }
#         buckets {
#           low_rank: 68
#           high_rank: 68
#           label: "ksAutotests/TutorialAdminErrors"
#           sample_count: 9.0
#         }
#         buckets {
#           low_rank: 69
#           high_rank: 69
#           label: "itselftools/media"
#           sample_count: 9.0
#         }
#         buckets {
#           low_rank: 70
#           high_rank: 70
#           label: "home-assistant/core"
#           sample_count: 9.0
#         }
#         buckets {
#           low_rank: 71
#           high_rank: 71
#           label: "exorde-labs/TestnetProtocol"
#           sample_count: 9.0
#         }
#         buckets {
#           low_rank: 72
#           high_rank: 72
#           label: "binary-com/deriv-app"
#           sample_count: 9.0
#         }
#         buckets {
#           low_rank: 73
#           high_rank: 73
#           label: "Snowflake-Labs/terraform-provider-snowflake"
#           sample_count: 9.0
#         }
#         buckets {
#           low_rank: 74
#           high_rank: 74
#           label: "pfcfai/autocommit2"
#           sample_count: 8.0
#         }
#         buckets {
#           low_rank: 75
#           high_rank: 75
#           label: "anangl/zephyr"
#           sample_count: 8.0
#         }
#         buckets {
#           low_rank: 76
#           high_rank: 76
#           label: "akum2/akum2"
#           sample_count: 8.0
#         }
#         buckets {
#           low_rank: 77
#           high_rank: 77
#           label: "SergeyIvanov87/pmccabe_visualizer_docker"
#           sample_count: 8.0
#         }
#         buckets {
#           low_rank: 78
#           high_rank: 78
#           label: "OpenBMB/MiniCPM"
#           sample_count: 8.0
#         }
#         buckets {
#           low_rank: 79
#           high_rank: 79
#           label: "vovannat/darknet-markets-links"
#           sample_count: 7.0
#         }
#         buckets {
#           low_rank: 80
#           high_rank: 80
#           label: "q9915977/tuchuang"
#           sample_count: 7.0
#         }
#         buckets {
#           low_rank: 81
#           high_rank: 81
#           label: "pass-culture/pass-culture-main"
#           sample_count: 7.0
#         }
#         buckets {
#           low_rank: 82
#           high_rank: 82
#           label: "kata-containers/kata-containers"
#           sample_count: 7.0
#         }
#         buckets {
#           low_rank: 83
#           high_rank: 83
#           label: "bugbounted/auto-commit"
#           sample_count: 7.0
#         }
#         buckets {
#           low_rank: 84
#           high_rank: 84
#           label: "Mohamed-Adel2/LeetCode-Solutions"
#           sample_count: 7.0
#         }
#         buckets {
#           low_rank: 85
#           high_rank: 85
#           label: "Jankyboy/LedgerSMB"
#           sample_count: 7.0
#         }
#         buckets {
#           low_rank: 86
#           high_rank: 86
#           label: "HadassaAvimor/Israel-Explorer"
#           sample_count: 7.0
#         }
#         buckets {
#           low_rank: 87
#           high_rank: 87
#           label: "DaiYu-233/YMCL"
#           sample_count: 7.0
#         }
#         buckets {
#           low_rank: 88
#           high_rank: 88
#           label: "CAAAB/plots"
#           sample_count: 7.0
#         }
#         buckets {
#           low_rank: 89
#           high_rank: 89
#           label: "yuuk-64-gi-0/unofficial_LiveSchedule_Data"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 90
#           high_rank: 90
#           label: "twfxjjbw/stockinfo"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 91
#           high_rank: 91
#           label: "ten238AZ/yv43iog4hmkv"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 92
#           high_rank: 92
#           label: "splashingdiamonds/pacer-courts"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 93
#           high_rank: 93
#           label: "scarrrr316/scarrrr316"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 94
#           high_rank: 94
#           label: "rmayr/rediffusion"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 95
#           high_rank: 95
#           label: "risingwavelabs/risingwave"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 96
#           high_rank: 96
#           label: "okxlin/appstore"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 97
#           high_rank: 97
#           label: "odoo/odoo"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 98
#           high_rank: 98
#           label: "microsoft/promptflow"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 99
#           high_rank: 99
#           label: "malinkang/wereadassets"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 100
#           high_rank: 100
#           label: "magicwave-io/go-ipfs"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 101
#           high_rank: 101
#           label: "kumamowa/evolverp-zeks"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 102
#           high_rank: 102
#           label: "harsh7516/harshad"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 103
#           high_rank: 103
#           label: "eyMarv/RambaZamba-DB"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 104
#           high_rank: 104
#           label: "esmf-org/esmf-test-artifacts"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 105
#           high_rank: 105
#           label: "eclipse-platform/eclipse.platform.swt"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 106
#           high_rank: 106
#           label: "apache/doris"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 107
#           high_rank: 107
#           label: "StarRocks/starrocks"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 108
#           high_rank: 108
#           label: "NixOS/nixpkgs"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 109
#           high_rank: 109
#           label: "NicN11/Germino-Silver"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 110
#           high_rank: 110
#           label: "BlaaSwe/The-Beast-Signalytic"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 111
#           high_rank: 111
#           label: "Bertik23/fit-status"
#           sample_count: 6.0
#         }
#         buckets {
#           low_rank: 112
#           high_rank: 112
#           label: "zomeru/zomeru"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 113
#           high_rank: 113
#           label: "wikionline/wikirobo"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 114
#           high_rank: 114
#           label: "thin-edge/thin-edge.io"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 115
#           high_rank: 115
#           label: "supervpnops/sl_for_ios_greenapp"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 116
#           high_rank: 116
#           label: "starkware-libs/starknet-specs"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 117
#           high_rank: 117
#           label: "scalr-automation/terraform-scalr-flat-mirror4"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 118
#           high_rank: 118
#           label: "roojs/roobuilder"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 119
#           high_rank: 119
#           label: "regro/cf-graph-countyfair"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 120
#           high_rank: 120
#           label: "refined-github/refined-github"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 121
#           high_rank: 121
#           label: "rebetooos/test"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 122
#           high_rank: 122
#           label: "rAlY2612MoBU/qb23mnvpr401"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 123
#           high_rank: 123
#           label: "prawn-test-production-rw/mg-service-test"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 124
#           high_rank: 124
#           label: "owenhunter4/React-Admin-Dashboard2"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 125
#           high_rank: 125
#           label: "owenbendavies/cms"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 126
#           high_rank: 126
#           label: "openshift/release"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 127
#           high_rank: 127
#           label: "godotengine/godot"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 128
#           high_rank: 128
#           label: "equinor/dm-core-packages"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 129
#           high_rank: 129
#           label: "digital-asset/daml"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 130
#           high_rank: 130
#           label: "diffplug/spotless"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 131
#           high_rank: 131
#           label: "ctc-uci/commit-the-change-website"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 132
#           high_rank: 132
#           label: "Vsonneveld/foroxity-genres"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 133
#           high_rank: 133
#           label: "Rohit496/SFDX-Complete"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 134
#           high_rank: 134
#           label: "Rashid-Shocho/Problem-Solving-with-Python-and-JAVA"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 135
#           high_rank: 135
#           label: "QywIT602/7yvysu7"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 136
#           high_rank: 136
#           label: "Lauretaad/Lauretaad1"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 137
#           high_rank: 137
#           label: "KaelSM/KaelSM"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 138
#           high_rank: 138
#           label: "JAORMX/bad-python"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 139
#           high_rank: 139
#           label: "Guillei/tu"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 140
#           high_rank: 140
#           label: "Expensify/App"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 141
#           high_rank: 141
#           label: "DataDog/datadog-agent"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 142
#           high_rank: 142
#           label: "BlaaSwe/Trend-Soaring-1min"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 143
#           high_rank: 143
#           label: "BayseIntelligence/site_fingerprints"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 144
#           high_rank: 144
#           label: "xiaoandy1974/test"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 145
#           high_rank: 145
#           label: "vitimlena/tor2web"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 146
#           high_rank: 146
#           label: "ursacomputing/crossbow"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 147
#           high_rank: 147
#           label: "ujala-singh/github-repository-dispatch-receiver"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 148
#           high_rank: 148
#           label: "thevickypedia/JarvisMonitor"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 149
#           high_rank: 149
#           label: "tIdoSeFOlazOD21/a58czrw02izie"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 150
#           high_rank: 150
#           label: "static-web-apps-testing-org/e2e-tests"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 151
#           high_rank: 151
#           label: "sambhav2612/sambhav2612"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 152
#           high_rank: 152
#           label: "qY652MojO/nnqkohue"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 153
#           high_rank: 153
#           label: "prawn-test-staging-rw/mergequeue_service_test_commit_status"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 154
#           high_rank: 154
#           label: "pranald123/marketresearchcommunity-"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 155
#           high_rank: 155
#           label: "openvinotoolkit/openvino"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 156
#           high_rank: 156
#           label: "next-step/atdd-subway-map"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 157
#           high_rank: 157
#           label: "navikt/syfomodiaperson"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 158
#           high_rank: 158
#           label: "mixman1177/live"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 159
#           high_rank: 159
#           label: "metersphere/metersphere"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 160
#           high_rank: 160
#           label: "marigold-ui/marigold"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 161
#           high_rank: 161
#           label: "lizongying/my-tv"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 162
#           high_rank: 162
#           label: "liferay-echo/liferay-portal"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 163
#           high_rank: 163
#           label: "kyma-project/lifecycle-manager"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 164
#           high_rank: 164
#           label: "kostyasabada/helper-test"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 165
#           high_rank: 165
#           label: "kohilainba/WalletAnvil"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 166
#           high_rank: 166
#           label: "katharz/cours-esilv-publish-packages"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 167
#           high_rank: 167
#           label: "jeena55/comOrg"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 168
#           high_rank: 168
#           label: "isomerpages/nlb-biblioasia"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 169
#           high_rank: 169
#           label: "irystocratanon/i.miss.irys.moe-supadata"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 170
#           high_rank: 170
#           label: "feedarchive/libera-newsbot-live"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 171
#           high_rank: 171
#           label: "expo/expo"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 172
#           high_rank: 172
#           label: "equinor/fusion-framework"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 173
#           high_rank: 173
#           label: "ePlus-DEV/top-github-users"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 174
#           high_rank: 174
#           label: "ePlus-DEV/metrics"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 175
#           high_rank: 175
#           label: "devhub-blue-sea-eu-west-3/org-public-empty-csc-repo-eu-west-3"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 176
#           high_rank: 176
#           label: "dani1552/GDSC_2023"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 177
#           high_rank: 177
#           label: "contao/contao"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 178
#           high_rank: 178
#           label: "azure-sdk/azure-sdk-for-js"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 179
#           high_rank: 179
#           label: "azure-sdk/azure-sdk-for-java"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 180
#           high_rank: 180
#           label: "archlinux/aur"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 181
#           high_rank: 181
#           label: "algotables/algotables.github.io"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 182
#           high_rank: 182
#           label: "WordPress/gutenberg"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 183
#           high_rank: 183
#           label: "WebKit/WebKit"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 184
#           high_rank: 184
#           label: "Sh4kE/k8s-projects"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 185
#           high_rank: 185
#           label: "Rotone8pyme/isn2jmn"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 186
#           high_rank: 186
#           label: "Rashadx0/Skrew"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 187
#           high_rank: 187
#           label: "PotatoesSkill/zelf"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 188
#           high_rank: 188
#           label: "PotatoesSkill/2"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 189
#           high_rank: 189
#           label: "Portkey-Wallet/portkey-wallet"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 190
#           high_rank: 190
#           label: "LucasXu0/AppFlowy"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 191
#           high_rank: 191
#           label: "Kong/kong"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 192
#           high_rank: 192
#           label: "Kanaries/graphic-walker"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 193
#           high_rank: 193
#           label: "InstantID/InstantID"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 194
#           high_rank: 194
#           label: "InkboxSoftware/excelCPU"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 195
#           high_rank: 195
#           label: "ForestAdmin/agent-nodejs"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 196
#           high_rank: 196
#           label: "FloatKasemtan/FloatKasemtan"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 197
#           high_rank: 197
#           label: "DaniMarques1/OriginsAssets"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 198
#           high_rank: 198
#           label: "DaniDeDos/DaniDeDos"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 199
#           high_rank: 199
#           label: "Certegy-Payment-Solutions/cashline.uptime.monitor"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 200
#           high_rank: 200
#           label: "Bahmni/openmrs-module-ipd-frontend"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 201
#           high_rank: 201
#           label: "ALFICA-Sistemas/LogConex"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 202
#           high_rank: 202
#           label: "19920513/ntdtv"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 203
#           high_rank: 203
#           label: "1024pix/pix"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 204
#           high_rank: 204
#           label: "zephyrproject-rtos/zephyr"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 205
#           high_rank: 205
#           label: "zed-industries/zed"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 206
#           high_rank: 206
#           label: "yogeshvar/yogeshvar"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 207
#           high_rank: 207
#           label: "yger/spikeinterface"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 208
#           high_rank: 208
#           label: "xataio/client-ts"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 209
#           high_rank: 209
#           label: "xamarin/xamarin-macios"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 210
#           high_rank: 210
#           label: "wiproSumanta/CustomToast"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 211
#           high_rank: 211
#           label: "wildfly-clustering/wildfly-clustering-tomcat"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 212
#           high_rank: 212
#           label: "vyos/vyos-1x"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 213
#           high_rank: 213
#           label: "umati/hackathon"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 214
#           high_rank: 214
#           label: "tursodatabase/libsql"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 215
#           high_rank: 215
#           label: "tomb003/yt"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 216
#           high_rank: 216
#           label: "tohgarashi/verified-commit"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 217
#           high_rank: 217
#           label: "toeverything/AFFiNE"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 218
#           high_rank: 218
#           label: "to-lutz/stmx-shop"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 219
#           high_rank: 219
#           label: "thoughtbot/upcase"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 220
#           high_rank: 220
#           label: "theakhinabraham/theakhinabraham"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 221
#           high_rank: 221
#           label: "the-technat/terraform-aws-eks-full"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 222
#           high_rank: 222
#           label: "taoliujun/json-beautiful-render"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 223
#           high_rank: 223
#           label: "tanushchauhan/csc-chapter-website"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 224
#           high_rank: 224
#           label: "systemli/prometheus-uptimerobot-exporter"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 225
#           high_rank: 225
#           label: "swaraj3455/sample_asprepo"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 226
#           high_rank: 226
#           label: "supershell2019/images"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 227
#           high_rank: 227
#           label: "status-im/airflow-dags"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 228
#           high_rank: 228
#           label: "spatial-model-editor/spatial-model-editor.github.io"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 229
#           high_rank: 229
#           label: "snakemake/snakemake-wrappers"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 230
#           high_rank: 230
#           label: "simonadamgyula/PygameHtmlPpt"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 231
#           high_rank: 231
#           label: "shortlink-org/shortlink"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 232
#           high_rank: 232
#           label: "segmentio/analytics-python"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 233
#           high_rank: 233
#           label: "scrappycito/git-bash-test"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 234
#           high_rank: 234
#           label: "scito/extract_otp_secrets"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 235
#           high_rank: 235
#           label: "scalr-automation/terraform-scalr-nested-mirror1"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 236
#           high_rank: 236
#           label: "scalr-automation/terraform-scalr-flat"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 237
#           high_rank: 237
#           label: "satisl/MAU"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 238
#           high_rank: 238
#           label: "sarvex/code-server"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 239
#           high_rank: 239
#           label: "sap-tutorials/btp-onboarding"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 240
#           high_rank: 240
#           label: "saby-integration/v8unpack"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 241
#           high_rank: 241
#           label: "rssysu/rssysu.github.io"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 242
#           high_rank: 242
#           label: "pytorch/pytorch"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 243
#           high_rank: 243
#           label: "publicissapient-france/who-is-2-turbo-web"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 244
#           high_rank: 244
#           label: "planetrenox/cute-github-init"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 245
#           high_rank: 245
#           label: "pingcap/tiflow"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 246
#           high_rank: 246
#           label: "peteoshea/website"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 247
#           high_rank: 247
#           label: "percona/everest-operator"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 248
#           high_rank: 248
#           label: "panoratech/Panora"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 249
#           high_rank: 249
#           label: "oxc-project/oxc"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 250
#           high_rank: 250
#           label: "orbs-network/tsv-widget"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 251
#           high_rank: 251
#           label: "openshift/lightspeed-service"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 252
#           high_rank: 252
#           label: "openfoodfacts/openfoodfacts-web"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 253
#           high_rank: 253
#           label: "onvista-media/slatify"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 254
#           high_rank: 254
#           label: "oferitz/YANG"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 255
#           high_rank: 255
#           label: "odoo-dev/odoo"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 256
#           high_rank: 256
#           label: "nrfconnect/sdk-nrf"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 257
#           high_rank: 257
#           label: "munue1/manue12345"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 258
#           high_rank: 258
#           label: "moraxy/mvg"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 259
#           high_rank: 259
#           label: "moodlehq/moodleapp"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 260
#           high_rank: 260
#           label: "mkarmark/swa3dfeeccf1f134ebb89899d3ed86a6ab8"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 261
#           high_rank: 261
#           label: "milvus-io/milvus"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 262
#           high_rank: 262
#           label: "microsoft/vscode"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 263
#           high_rank: 263
#           label: "microsoft/kiota"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 264
#           high_rank: 264
#           label: "maumitabhaumik/maumitabhaumik.github.io"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 265
#           high_rank: 265
#           label: "mariannejordan20/DTR2"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 266
#           high_rank: 266
#           label: "majorbalintistvan/pygame_html-ppt"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 267
#           high_rank: 267
#           label: "lucaboesch/moodle"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 268
#           high_rank: 268
#           label: "livingdocsIO/documentation"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 269
#           high_rank: 269
#           label: "leo-t-88/leo-t-88.github.io"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 270
#           high_rank: 270
#           label: "lakkaru/lakkaru-clothing-react-capstone"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 271
#           high_rank: 271
#           label: "krot4u/Public_scripts"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 272
#           high_rank: 272
#           label: "kinjalsoftnoesis/Test"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 273
#           high_rank: 273
#           label: "keptn/lifecycle-toolkit"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 274
#           high_rank: 274
#           label: "katharz/cours-esilv-test-with-actions"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 275
#           high_rank: 275
#           label: "kandiaro01/gee"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 276
#           high_rank: 276
#           label: "kamraniswinner/hello-world"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 277
#           high_rank: 277
#           label: "kalviumcommunity/s46_Storobbery"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 278
#           high_rank: 278
#           label: "jurikri/webhosting"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 279
#           high_rank: 279
#           label: "jisuyoun/jisuyoun.github.io"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 280
#           high_rank: 280
#           label: "janithahn/janithahn"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 281
#           high_rank: 281
#           label: "isomerpages/ogp-scams-duplicate"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 282
#           high_rank: 282
#           label: "hookzof/socks5_list"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 283
#           high_rank: 283
#           label: "hmcts/prl-cos-api"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 284
#           high_rank: 284
#           label: "hmcts/ethos-repl-docmosis-service"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 285
#           high_rank: 285
#           label: "himlpplm/himlpplm.github.io"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 286
#           high_rank: 286
#           label: "highcharts/highcharts"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 287
#           high_rank: 287
#           label: "haikuacademy/B11G04-SQL"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 288
#           high_rank: 288
#           label: "h4sh5/pypi-auto-scanner"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 289
#           high_rank: 289
#           label: "grafana/xk6-browser"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 290
#           high_rank: 290
#           label: "gracefengj3/hertoport"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 291
#           high_rank: 291
#           label: "graasp/graasp-builder"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 292
#           high_rank: 292
#           label: "ggerganov/llama.cpp"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 293
#           high_rank: 293
#           label: "frequenz-floss/frequenz-sdk-python"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 294
#           high_rank: 294
#           label: "findy-network/findy-issuer-tool"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 295
#           high_rank: 295
#           label: "ffflorian/exercism"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 296
#           high_rank: 296
#           label: "ethan-frot/Jeux-Intro-Digital-Event-2324"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 297
#           high_rank: 297
#           label: "estevenson9/sketch"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 298
#           high_rank: 298
#           label: "equinor/ecalc"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 299
#           high_rank: 299
#           label: "elastic/elasticsearch"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 300
#           high_rank: 300
#           label: "dfinity/nns-dapp"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 301
#           high_rank: 301
#           label: "demccormack/piplayer"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 302
#           high_rank: 302
#           label: "deepseek-ai/DeepSeek-Coder"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 303
#           high_rank: 303
#           label: "cours-esilv/02-test-with-actions-engenouadje"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 304
#           high_rank: 304
#           label: "coinbase/build-onchain-apps"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 305
#           high_rank: 305
#           label: "cargo-bins/cargo-quickinstall"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 306
#           high_rank: 306
#           label: "brianchandotcom/liferay-portal"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 307
#           high_rank: 307
#           label: "botati/BAYOGRAM"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 308
#           high_rank: 308
#           label: "boostcampwm2023/web09-MagicConch"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 309
#           high_rank: 309
#           label: "blogspotvn/tool"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 310
#           high_rank: 310
#           label: "benchmark-action/github-action-benchmark"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 311
#           high_rank: 311
#           label: "azure-sdk/azure-sdk-for-net"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 312
#           high_rank: 312
#           label: "atc0005/mysql2sqlite"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 313
#           high_rank: 313
#           label: "arextest/arex-api"
# ...
#           label: "ADHITHYA2004"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7523
#           high_rank: 7523
#           label: "ACsauscher"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7524
#           high_rank: 7524
#           label: "ACCLE123"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7525
#           high_rank: 7525
#           label: "ABINESHA2003"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7526
#           high_rank: 7526
#           label: "ABHISHEKPATIL0880"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7527
#           high_rank: 7527
#           label: "AAISSJ"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7528
#           high_rank: 7528
#           label: "AAABBBCCCAAAA"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7529
#           high_rank: 7529
#           label: "A-Kopstad"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7530
#           high_rank: 7530
#           label: "999eagle"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7531
#           high_rank: 7531
#           label: "991233liu"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7532
#           high_rank: 7532
#           label: "95hyun"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7533
#           high_rank: 7533
#           label: "94fzb"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7534
#           high_rank: 7534
#           label: "937026"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7535
#           high_rank: 7535
#           label: "930C"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7536
#           high_rank: 7536
#           label: "929359291"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7537
#           high_rank: 7537
#           label: "91fabbai91"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7538
#           high_rank: 7538
#           label: "9156877570"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7539
#           high_rank: 7539
#           label: "9034725985"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7540
#           high_rank: 7540
#           label: "9-neet"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7541
#           high_rank: 7541
#           label: "8thgencore"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7542
#           high_rank: 7542
#           label: "8Q757"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7543
#           high_rank: 7543
#           label: "861692276"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7544
#           high_rank: 7544
#           label: "7mukunda"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7545
#           high_rank: 7545
#           label: "7878877858"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7546
#           high_rank: 7546
#           label: "752659984"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7547
#           high_rank: 7547
#           label: "721806280"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7548
#           high_rank: 7548
#           label: "7006"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7549
#           high_rank: 7549
#           label: "6eom9eun"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7550
#           high_rank: 7550
#           label: "69robinhood69"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7551
#           high_rank: 7551
#           label: "69ggg69"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7552
#           high_rank: 7552
#           label: "648652443"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7553
#           high_rank: 7553
#           label: "64410047"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7554
#           high_rank: 7554
#           label: "4z0t"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7555
#           high_rank: 7555
#           label: "4th-avenue"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7556
#           high_rank: 7556
#           label: "4eUeP"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7557
#           high_rank: 7557
#           label: "4abishai"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7558
#           high_rank: 7558
#           label: "4SAMU"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7559
#           high_rank: 7559
#           label: "463214114"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7560
#           high_rank: 7560
#           label: "2Circle"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7561
#           high_rank: 7561
#           label: "2814109"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7562
#           high_rank: 7562
#           label: "27kanghan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7563
#           high_rank: 7563
#           label: "2456768374"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7564
#           high_rank: 7564
#           label: "242lee"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7565
#           high_rank: 7565
#           label: "20Maribel22"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7566
#           high_rank: 7566
#           label: "20JULIA"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7567
#           high_rank: 7567
#           label: "20ArmstrongD"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7568
#           high_rank: 7568
#           label: "2001sree"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7569
#           high_rank: 7569
#           label: "20-08233Ken"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7570
#           high_rank: 7570
#           label: "1yzamiryz1"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7571
#           high_rank: 7571
#           label: "1token"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7572
#           high_rank: 7572
#           label: "1sakp"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7573
#           high_rank: 7573
#           label: "1LoveViolet"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7574
#           high_rank: 7574
#           label: "1986webdeveloper"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7575
#           high_rank: 7575
#           label: "1902520039"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7576
#           high_rank: 7576
#           label: "18148764734"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7577
#           high_rank: 7577
#           label: "18080866236"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7578
#           high_rank: 7578
#           label: "16sea16"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7579
#           high_rank: 7579
#           label: "1625968092"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7580
#           high_rank: 7580
#           label: "1457716957"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7581
#           high_rank: 7581
#           label: "13xforever"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7582
#           high_rank: 7582
#           label: "13badjei"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7583
#           high_rank: 7583
#           label: "13837678992"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7584
#           high_rank: 7584
#           label: "1327614618"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7585
#           high_rank: 7585
#           label: "12deeksha"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7586
#           high_rank: 7586
#           label: "1244862942"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7587
#           high_rank: 7587
#           label: "123Jun321"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7588
#           high_rank: 7588
#           label: "123CR0001"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7589
#           high_rank: 7589
#           label: "1120562641"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7590
#           high_rank: 7590
#           label: "10adnan75"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7591
#           high_rank: 7591
#           label: "10Derozan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7592
#           high_rank: 7592
#           label: "100-0"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7593
#           high_rank: 7593
#           label: "0xSachinK"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7594
#           high_rank: 7594
#           label: "0xB10C"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7595
#           high_rank: 7595
#           label: "0x64"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7596
#           high_rank: 7596
#           label: "0with1"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7597
#           high_rank: 7597
#           label: "0mer99"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7598
#           high_rank: 7598
#           label: "0kurk4"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7599
#           high_rank: 7599
#           label: "0Jaeyoung0"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7600
#           high_rank: 7600
#           label: "0396923"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7601
#           high_rank: 7601
#           label: "0323pin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7602
#           high_rank: 7602
#           label: "02ggang9"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7603
#           high_rank: 7603
#           label: "010101aa"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7604
#           high_rank: 7604
#           label: "007sunny"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7605
#           high_rank: 7605
#           label: "000kira"
#           sample_count: 1.0
#         }
#       }
#     }
#   }
#   features {
#     name: "timestamp"
#     num_stats {
#       common_stats {
#         num_non_missing: 15630
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 1563.0
#           }
#           type: QUANTILES
#         }
#       }
#       mean: 1.7068639227597302e+18
#       std_dev: 1654457293730.8374
#       min: 1.706861112023344e+18
#       median: 1.7068638812258455e+18
#       max: 1.706866843628641e+18
#       histograms {
#         buckets {
#           low_value: 1.706861112023344e+18
#           high_value: 1.7068616851838738e+18
#           sample_count: 1590.0
#         }
#         buckets {
#           low_value: 1.7068616851838738e+18
#           high_value: 1.7068622583444035e+18
#           sample_count: 1620.0
#         }
#         buckets {
#           low_value: 1.7068622583444035e+18
#           high_value: 1.706862831504933e+18
#           sample_count: 1650.0
#         }
#         buckets {
#           low_value: 1.706862831504933e+18
#           high_value: 1.7068634046654628e+18
#           sample_count: 1620.0
#         }
#         buckets {
#           low_value: 1.7068634046654628e+18
#           high_value: 1.7068639778259927e+18
#           sample_count: 1620.0
#         }
#         buckets {
#           low_value: 1.7068639778259927e+18
#           high_value: 1.7068645509865224e+18
#           sample_count: 1620.0
#         }
#         buckets {
#           low_value: 1.7068645509865224e+18
#           high_value: 1.706865124147052e+18
#           sample_count: 1620.0
#         }
#         buckets {
#           low_value: 1.706865124147052e+18
#           high_value: 1.7068656973075817e+18
#           sample_count: 1050.0
#         }
#         buckets {
#           low_value: 1.7068656973075817e+18
#           high_value: 1.7068662704681114e+18
#           sample_count: 1620.0
#         }
#         buckets {
#           low_value: 1.7068662704681114e+18
#           high_value: 1.706866843628641e+18
#           sample_count: 1620.0
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 1.706861112023344e+18
#           high_value: 1.706861675890106e+18
#           sample_count: 1563.0
#         }
#         buckets {
#           low_value: 1.706861675890106e+18
#           high_value: 1.7068622267795525e+18
#           sample_count: 1563.0
#         }
#         buckets {
#           low_value: 1.7068622267795525e+18
#           high_value: 1.706862778416132e+18
#           sample_count: 1563.0
#         }
#         buckets {
#           low_value: 1.706862778416132e+18
#           high_value: 1.7068633294889626e+18
#           sample_count: 1563.0
#         }
#         buckets {
#           low_value: 1.7068633294889626e+18
#           high_value: 1.7068638812258455e+18
#           sample_count: 1563.0
#         }
#         buckets {
#           low_value: 1.7068638812258455e+18
#           high_value: 1.7068644319303045e+18
#           sample_count: 1563.0
#         }
#         buckets {
#           low_value: 1.7068644319303045e+18
#           high_value: 1.706864984386935e+18
#           sample_count: 1563.0
#         }
#         buckets {
#           low_value: 1.706864984386935e+18
#           high_value: 1.7068657343703603e+18
#           sample_count: 1563.0
#         }
#         buckets {
#           low_value: 1.7068657343703603e+18
#           high_value: 1.706866288776116e+18
#           sample_count: 1563.0
#         }
#         buckets {
#           low_value: 1.706866288776116e+18
#           high_value: 1.706866843628641e+18
#           sample_count: 1563.0
#         }
#         type: QUANTILES
#       }
#     }
#   }
# }

# %%
protostr = base64.b64encode(proto.SerializeToString()).decode("utf-8")
HTML_TEMPLATE = """
        <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
        <link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html" >
        <facets-overview id="elem"></facets-overview>
        <script>
          document.querySelector("#elem").protoInput = "{protostr}";
        </script>"""
html = HTML_TEMPLATE.format(protostr=protostr)
display(HTML(html))
# Out:
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#         <link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html" >
#         <facets-overview id="elem"></facets-overview>
#         <script>
#           document.querySelector("#elem").protoInput = "...";
#         </script>
