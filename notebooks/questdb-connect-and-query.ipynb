# %% [markdown]
# # QuestDB Connect and Query
#
# ## Querying QuestDB using the PostgreSQL wire-protocol
#
# QuestDB is compatible with the Postgresql wire-protocol, which means you can use any postgresql compatible library to connect, send queries, and get results back. Please note that QuestDB is not built on top of Postgresql and it doesn't support its whole function set.
#
# Moreover, QuestDB provides [its own extensions](https://questdb.io/docs/concept/sql-extensions/) to work with time-series data. However, at the protocol level the SQL is not validated, so as long as your Postgresql client can connect, send queries, and read results back, you can use it to query QuestDB.

# %%
import psycopg as pg
import time

# Connect to an existing QuestDB instance

conn_str = 'user=admin password=quest host=questdb port=8812 dbname=qdb'
with pg.connect(conn_str, autocommit=True) as connection:

    # Open a cursor to perform database operations

    with connection.cursor() as cur:

        #Query the database and obtain data as Python objects.

        cur.execute('SELECT * FROM MARKETBROKER.LOCAL.TICKSTREAM_TOPIC LIMIT 10;')
        records = cur.fetchall()
        for row in records:
            print(row)

# the connection is now closed
# Out:
# (6374, 17972.8, 17971.9, 17972.3, datetime.datetime(2024, 4, 25, 7, 28, 49, 652000))
# (6374, 17973.3, 17972.4, 17972.8, datetime.datetime(2024, 4, 25, 7, 28, 49, 988000))
# (6374, 17972.8, 17971.9, 17972.3, datetime.datetime(2024, 4, 25, 7, 28, 50, 475000))
# (6374, 17973.3, 17972.4, 17972.8, datetime.datetime(2024, 4, 25, 7, 28, 50, 934000))
# (6374, 17972.8, 17971.9, 17972.3, datetime.datetime(2024, 4, 25, 7, 28, 51, 741000))
# (6374, 17972.3, 17971.4, 17971.8, datetime.datetime(2024, 4, 25, 7, 28, 52, 540000))
# (6374, 17972.8, 17971.9, 17972.3, datetime.datetime(2024, 4, 25, 7, 28, 53, 58000))
# (6374, 17973.8, 17972.9, 17973.3, datetime.datetime(2024, 4, 25, 7, 28, 53, 108000))
# (6374, 17972.3, 17971.4, 17971.8, datetime.datetime(2024, 4, 25, 7, 28, 53, 230000))
# (6374, 17971.3, 17970.4, 17970.8, datetime.datetime(2024, 4, 25, 7, 28, 53, 712000))

# %% [markdown]
# ## Querying QuestDB using the REST API
#
# It is possible to use QuestDB's API from any HTTP client. As an example we will use the Python `requests` library to issue the same query we executed above

# %%
import requests

host = 'http://questdb:9000'

sql_query = 'SELECT * FROM MARKETBROKER.LOCAL.TICKSTREAM_TOPIC LIMIT 10;'

try:
    response = requests.get(
        host + '/exec',
        params={'query': sql_query}).json()
    for row in response['dataset']:
        print(row)
except requests.exceptions.RequestException as e:
    print(f'Error: {e}')
# Out:
# [6374, 17972.8, 17971.9, 17972.3, '2024-04-25T07:28:49.652000Z']
# [6374, 17973.3, 17972.4, 17972.8, '2024-04-25T07:28:49.988000Z']
# [6374, 17972.8, 17971.9, 17972.3, '2024-04-25T07:28:50.475000Z']
# [6374, 17973.3, 17972.4, 17972.8, '2024-04-25T07:28:50.934000Z']
# [6374, 17972.8, 17971.9, 17972.3, '2024-04-25T07:28:51.741000Z']
# [6374, 17972.3, 17971.4, 17971.8, '2024-04-25T07:28:52.540000Z']
# [6374, 17972.8, 17971.9, 17972.3, '2024-04-25T07:28:53.058000Z']
# [6374, 17973.8, 17972.9, 17973.3, '2024-04-25T07:28:53.108000Z']
# [6374, 17972.3, 17971.4, 17971.8, '2024-04-25T07:28:53.230000Z']
# [6374, 17971.3, 17970.4, 17970.8, '2024-04-25T07:28:53.712000Z']

# %% [markdown]
# ## Querying QuestDB using the REST API from the command line
#
# You can of course use any command line tools, like `curl` to execute queries on questdb. This also allows you to run DDL statements and execute some admin tasks

# %%
# !curl -G --silent --data-urlencode "query=SELECT * FROM MARKETBROKER.LOCAL.TICKSTREAM_TOPIC LIMIT 10;"  http://questdb:9000/exec | json_pp
# Out:
# {
#    "columns" : [
#       {
#          "name" : "q",
#          "type" : "LONG"
#       },
#       {
#          "name" : "a",
#          "type" : "DOUBLE"
#       },
#       {
#          "name" : "b",
#          "type" : "DOUBLE"
#       },
#       {
#          "name" : "m",
#          "type" : "DOUBLE"
#       },
#       {
#          "name" : "timestamp",
#          "type" : "TIMESTAMP"
#       }
#    ],
#    "count" : 10,
#    "dataset" : [
#       [
#          6374,
#          17972.8,
#          17971.9,
#          17972.3,
#          "2024-04-25T07:28:49.652000Z"
#       ],
#       [
#          6374,
#          17973.3,
#          17972.4,
#          17972.8,
#          "2024-04-25T07:28:49.988000Z"
#       ],
#       [
#          6374,
#          17972.8,
#          17971.9,
#          17972.3,
#          "2024-04-25T07:28:50.475000Z"
#       ],
#       [
#          6374,
#          17973.3,
#          17972.4,
#          17972.8,
#          "2024-04-25T07:28:50.934000Z"
#       ],
#       [
#          6374,
#          17972.8,
#          17971.9,
#          17972.3,
#          "2024-04-25T07:28:51.741000Z"
#       ],
#       [
#          6374,
#          17972.3,
#          17971.4,
#          17971.8,
#          "2024-04-25T07:28:52.540000Z"
#       ],
#       [
#          6374,
#          17972.8,
#          17971.9,
#          17972.3,
#          "2024-04-25T07:28:53.058000Z"
#       ],
#       [
#          6374,
#          17973.8,
#          17972.9,
#          17973.3,
#          "2024-04-25T07:28:53.108000Z"
#       ],
#       [
#          6374,
#          17972.3,
#          17971.4,
#          17971.8,
#          "2024-04-25T07:28:53.230000Z"
#       ],
#       [
#          6374,
#          17971.3,
#          17970.4,
#          17970.8,
#          "2024-04-25T07:28:53.712000Z"
#       ]
#    ],
#    "query" : "SELECT * FROM MARKETBROKER.LOCAL.TICKSTREAM_TOPIC LIMIT 10;",
#    "timestamp" : 4
# }
